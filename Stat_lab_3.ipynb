# %% [markdown]
# <a href="https://colab.research.google.com/github/apester/IME/blob/main/Stat_lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=10)
ridge.fit(X.reshape(-1,1), Y)

plt.scatter(X,Y)
plt.plot(X, ridge.predict(X.reshape(-1,1)), color='green')
plt.show()
